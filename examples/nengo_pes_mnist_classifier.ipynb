# %%
# !pip install nengo nengo-dl

# %%
import nengo
import nengo_dl
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from sklearn.metrics import classification_report

# %%
class Dataset:
  NUM_CLASSES = 10
  DIM = 28 * 28

  def __init__(self, time_per_data: float):
    (train_x, train_y), (test_x, test_y) = tf.keras.datasets.mnist.load_data()

    self.train_x = train_x.reshape([train_x.shape[0], self.DIM])
    self.train_y = np.eye(self.NUM_CLASSES)[train_y]
    self.test_x = test_x.reshape([test_x.shape[0], self.DIM])
    self.test_y = np.eye(self.NUM_CLASSES)[test_y]

    self.time_per_data = time_per_data
    self._is_test = False
    self._start_from = 0.0

  def __len__(self):
    return len(self.test_y) if self._is_test else len(self.train_y)

  def train(self, start_from: float=0.0):
    self._is_test = False
    self._start_from = start_from
  
  def test(self, start_from: float=0.0):
    self._is_test = True
    self._start_from = start_from

  def get_x(self, t: float) -> np.ndarray:
    t += self._start_from
    x = self.test_x if self._is_test else self.train_x
    idx = int(t // self.time_per_data) % len(x)
    return x[idx]

  def get_y(self, t: float) -> np.ndarray:
    t += self._start_from
    y = self.test_y if self._is_test else self.test_y
    idx = int(t // self.time_per_data) % len(y)
    return y[idx]

  @property
  def duration(self) -> float:
    return len(self) * self.time_per_data

# %%
time_per_data = 0.1
dataset = Dataset(time_per_data)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %%
model = nengo.Network()
with model:
  input_node = nengo.Node(dataset.get_x, size_out=dataset.DIM)
  target_node = nengo.Node(dataset.get_y, size_out=dataset.NUM_CLASSES)
  input = nengo.Ensemble(n_neurons=768, dimensions=dataset.DIM)
  target = nengo.Ensemble(n_neurons=64, dimensions=dataset.NUM_CLASSES)

  nengo.Connection(input_node, input)
  nengo.Connection(target_node, target)

  pred = nengo.Ensemble(n_neurons=64, dimensions=dataset.NUM_CLASSES)
  pred_conn = nengo.Connection(input, pred, transform=np.ones([dataset.NUM_CLASSES, dataset.DIM]))

  pred_p = nengo.Probe(pred, synapse=0.01)
  target_p = nengo.Probe(target, synapse=0.01)

# %%
def evaluate(sim: nengo_dl.Simulator):
  """Evaluate simulate results, calculate and print metrics"""
  timestep_of_data = int(time_per_data / sim.dt)
  timestep = int(sim.time / sim.dt)
  timestep -= timestep % timestep_of_data

  preds = sim.data[pred_p].reshape([timestep // timestep_of_data, timestep_of_data, -1]).mean(axis=1).argmax(-1)
  labels = sim.data[target_p].reshape([timestep // timestep_of_data, timestep_of_data, -1]).mean(axis=1).argmax(-1)

  return labels, preds

# %% [markdown]
# # Test Before Training

# %%
with nengo_dl.Simulator(model, device='/cpu:0') as sim:
  dataset.test()
  # Use Only 100 examples for speed
  sim.run(dataset.time_per_data * 100)
  print(classification_report(*evaluate(sim)))
# Out:
# Build finished in 0:00:02
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:00:07
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         8
#            1       0.00      0.00      0.00        14
#            2       0.00      0.00      0.00         8
#            3       0.11      1.00      0.20        11
#            4       0.00      0.00      0.00        14
#            5       0.00      0.00      0.00         7
#            6       0.00      0.00      0.00        10
#            7       0.00      0.00      0.00        15
#            8       0.00      0.00      0.00         2
#            9       0.00      0.00      0.00        11
#
#     accuracy                           0.11       100
#    macro avg       0.01      0.10      0.02       100
# weighted avg       0.01      0.11      0.02       100
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # Train & Test

# %%
learning_rate = 2e-4
epochs = 5
batch_size = 1000
num_train_data_divider = 12

model_backup_path = "./model.bak"

# %%
with model:
  err = nengo.Ensemble(64, dimensions=dataset.NUM_CLASSES)
  nengo.Connection(pred, err)
  nengo.Connection(target, err, transform=-1)

  pred_conn.learning_rule_type = nengo.learning_rules.PES(learning_rate=learning_rate)
  err_conn = nengo.Connection(err, pred_conn.learning_rule)

# %%
with nengo_dl.Simulator(model, device='/cpu:0') as sim:
  sim.save_params(model_backup_path)

for i in range(1, epochs+1):
  train_labels = []
  train_preds = []

  print(f"[+] Start training {i} epoch")
  dataset.train()
  for j in range(len(dataset) // batch_size // num_train_data_divider):
    with nengo_dl.Simulator(model, device="/cpu:0") as sim:
      # Load to ignore learning with test dataset
      sim.load_params(model_backup_path)

      dataset.train(start_from=batch_size * j * dataset.time_per_data)
      sim.run(batch_size * dataset.time_per_data)
      labels, preds = evaluate(sim)
      train_labels.extend(labels)
      train_preds.extend(preds)

      # Save model params
      sim.save_params(model_backup_path)
  print("[+] Training Metrics")
  print(classification_report(train_labels, train_preds))
  
  test_labels = []
  test_preds = []
  dataset.test()
  print(f"[+] Start Test {i} epoch")
  for j in range(len(dataset) // batch_size):
    with nengo_dl.Simulator(model, device="/cpu:0") as sim:
      dataset.test(start_from = batch_size * j * dataset.time_per_data)
      sim.run(batch_size * dataset.time_per_data)
      labels, preds = evaluate(sim)
      test_labels.extend(labels)
      test_preds.extend(preds)
  
  print("[+] Test Metrics")
  print(classification_report(test_labels, test_preds))
# Out:
# Build finished in 0:00:02
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# [+] Start training 1 epoch
# Build finished in 0:00:02
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:10
# Build finished in 0:00:02
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:27
# Build finished in 0:00:02
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:09
# Build finished in 0:00:17
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# |               #             Simulating                              | 0:01:10WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7ff6b9b379e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7ff6b9b379e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Simulation finished in 0:01:10
# Build finished in 0:00:02
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# |                       #     Simulating                              | 0:01:11WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7ff6c8ed8200> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7ff6c8ed8200> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Simulation finished in 0:01:11
# [+] Training Metrics
#               precision    recall  f1-score   support
#
#            0       0.03      0.10      0.04        21
#            1       0.30      0.06      0.11       500
#            2       0.00      0.00      0.00         0
#            3       0.00      0.00      0.00         0
#            4       0.09      0.27      0.14       474
#            5       0.23      0.47      0.31       419
#            6       0.05      0.01      0.02       654
#            7       0.07      0.05      0.06       532
#            8       0.00      0.00      0.00         0
#            9       0.41      0.14      0.21      2400
#
#     accuracy                           0.15      5000
#    macro avg       0.12      0.11      0.09      5000
# weighted avg       0.27      0.15      0.16      5000
#
# [+] Start Test 1 epoch
# |                     Building network (0%)                    | ETA:  --:--:--
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Build finished in 0:00:02
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:11
# Build finished in 0:00:02
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:09
# Build finished in 0:00:18
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:11
# Build finished in 0:00:02
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:27
# Build finished in 0:00:02
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:27
# Build finished in 0:00:02
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:10
# Build finished in 0:00:02
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:27
# Build finished in 0:00:02
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:10
# Build finished in 0:00:02
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:11
# Build finished in 0:00:02
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:10
# [+] Test Metrics
#               precision    recall  f1-score   support
#
#            0       0.85      0.88      0.86       980
#            1       0.83      0.90      0.87      1135
#            2       0.82      0.77      0.79      1032
#            3       0.78      0.80      0.79      1010
#            4       0.80      0.76      0.78       982
#            5       0.81      0.70      0.75       892
#            6       0.81      0.83      0.82       958
#            7       0.80      0.85      0.83      1028
#            8       0.77      0.74      0.76       974
#            9       0.75      0.78      0.76      1009
#
#     accuracy                           0.80     10000
#    macro avg       0.80      0.80      0.80     10000
# weighted avg       0.80      0.80      0.80     10000
#
# [+] Start training 2 epoch
# Build finished in 0:00:02
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:13
# Build finished in 0:00:14
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:12
# Build finished in 0:00:02
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:12
# Build finished in 0:00:15
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:09
# Build finished in 0:00:02
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:27
# [+] Training Metrics
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        46
#            1       0.44      0.62      0.52       798
#            2       0.00      0.00      0.00        20
#            3       0.00      0.00      0.00       101
#            4       0.06      0.02      0.03      2172
#            5       0.00      0.00      0.00       101
#            6       0.00      0.00      0.00       197
#            7       0.00      0.00      0.00       210
#            8       0.00      0.00      0.00         2
#            9       0.02      0.01      0.02      1353
#
#     accuracy                           0.11      5000
#    macro avg       0.05      0.07      0.06      5000
# weighted avg       0.10      0.11      0.10      5000
#
# [+] Start Test 2 epoch
# Build finished in 0:00:02
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:27
# Build finished in 0:00:02
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:11
# Build finished in 0:00:02
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:11
# Build finished in 0:00:02
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:15
# Build finished in 0:00:02
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:27
# Build finished in 0:00:02
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:12
# Build finished in 0:00:15
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:12
# Build finished in 0:00:02
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:12
# Build finished in 0:00:02
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:13
# Build finished in 0:00:02
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:14
# [+] Test Metrics
#               precision    recall  f1-score   support
#
#            0       0.79      0.85      0.82       980
#            1       0.86      0.87      0.87      1135
#            2       0.82      0.77      0.80      1032
#            3       0.79      0.79      0.79      1010
#            4       0.75      0.75      0.75       982
#            5       0.74      0.73      0.73       892
#            6       0.82      0.77      0.79       958
#            7       0.75      0.85      0.80      1028
#            8       0.79      0.71      0.75       974
#            9       0.75      0.76      0.75      1009
#
#     accuracy                           0.79     10000
#    macro avg       0.79      0.79      0.79     10000
# weighted avg       0.79      0.79      0.79     10000
#
# [+] Start training 3 epoch
# Build finished in 0:00:14
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:13
# Build finished in 0:00:02
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:14
# Build finished in 0:00:02
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:11
# Build finished in 0:00:02
# Optimization finished in 0:00:00
# Construction finished in 0:00:01
# Simulation finished in 0:01:13
# Build finished in 0:00:03
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:11
# [+] Training Metrics
#               precision    recall  f1-score   support
#
#            0       0.53      0.45      0.49       573
#            1       0.00      0.00      0.00       191
#            2       0.10      0.09      0.09       699
#            3       0.03      0.10      0.05       185
#            4       0.00      0.00      0.00       726
#            5       0.00      0.00      0.00       881
#            6       0.00      0.00      0.00       528
#            7       0.00      0.00      0.00       148
#            8       0.37      0.05      0.09       977
#            9       0.00      0.00      0.00        92
#
#     accuracy                           0.08      5000
#    macro avg       0.10      0.07      0.07      5000
# weighted avg       0.15      0.08      0.09      5000
#
# [+] Start Test 3 epoch
# Build finished in 0:00:02
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:13
# Build finished in 0:00:02
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:14
# Build finished in 0:00:02
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:14
# Build finished in 0:00:13
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:12
# Build finished in 0:00:02
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:27
# Build finished in 0:00:02
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:11
# Build finished in 0:00:02
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:11
# Build finished in 0:00:02
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:12
# Build finished in 0:00:02
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:17
# Build finished in 0:00:03
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:13
# [+] Test Metrics
#               precision    recall  f1-score   support
#
#            0       0.85      0.86      0.86       980
#            1       0.81      0.91      0.85      1135
#            2       0.78      0.79      0.78      1032
#            3       0.76      0.81      0.78      1010
#            4       0.75      0.76      0.76       982
#            5       0.78      0.68      0.73       892
#            6       0.82      0.83      0.82       958
#            7       0.87      0.82      0.84      1028
#            8       0.75      0.76      0.76       974
#            9       0.77      0.72      0.75      1009
#
#     accuracy                           0.80     10000
#    macro avg       0.80      0.79      0.79     10000
# weighted avg       0.80      0.80      0.79     10000
#
# [+] Start training 4 epoch
# Build finished in 0:00:03
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:13
# Build finished in 0:00:02
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:27
# Build finished in 0:00:02
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:14
# Build finished in 0:00:13
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:15
# Build finished in 0:00:03
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:14
# [+] Training Metrics
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.00      0.00      0.00       444
#            2       0.11      0.12      0.12       649
#            3       0.00      0.00      0.00       562
#            4       0.00      0.00      0.00       223
#            5       0.76      0.23      0.36      1395
#            6       0.00      0.00      0.00        82
#            7       0.38      0.27      0.31      1059
#            8       0.26      0.37      0.30       500
#            9       0.00      0.00      0.00        86
#
#     accuracy                           0.17      5000
#    macro avg       0.15      0.10      0.11      5000
# weighted avg       0.33      0.17      0.21      5000
#
# [+] Start Test 4 epoch
# Build finished in 0:00:02
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:14
# Build finished in 0:00:13
# Optimization finished in 0:00:00
# Construction finished in 0:00:01
# Simulation finished in 0:01:15
# Build finished in 0:00:02
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:13
# Build finished in 0:00:13
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:15
# Build finished in 0:00:02
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:12
# Build finished in 0:00:03
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:27
# Build finished in 0:00:02
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:13
# Build finished in 0:00:14
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:13
# Build finished in 0:00:15
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:13
# Build finished in 0:00:03
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:12
# [+] Test Metrics
#               precision    recall  f1-score   support
#
#            0       0.87      0.83      0.85       980
#            1       0.88      0.88      0.88      1135
#            2       0.80      0.82      0.81      1032
#            3       0.76      0.82      0.78      1010
#            4       0.73      0.79      0.76       982
#            5       0.75      0.70      0.72       892
#            6       0.80      0.84      0.82       958
#            7       0.80      0.82      0.81      1028
#            8       0.78      0.71      0.74       974
#            9       0.76      0.71      0.73      1009
#
#     accuracy                           0.79     10000
#    macro avg       0.79      0.79      0.79     10000
# weighted avg       0.79      0.79      0.79     10000
#
# [+] Start training 5 epoch
# Build finished in 0:00:15
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:11
# Build finished in 0:00:02
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:14
# Build finished in 0:00:13
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:11
# Build finished in 0:00:02
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:11
# Build finished in 0:00:03
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:15
# [+] Training Metrics
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       886
#            1       0.00      0.00      0.00        46
#            2       0.17      0.06      0.09      1404
#            3       0.00      0.01      0.01       148
#            4       0.00      0.00      0.00       290
#            5       0.19      0.60      0.28       313
#            6       0.24      0.16      0.19       232
#            7       0.01      0.02      0.02       687
#            8       0.00      0.00      0.00       893
#            9       0.00      0.00      0.00       101
#
#     accuracy                           0.06      5000
#    macro avg       0.06      0.08      0.06      5000
# weighted avg       0.07      0.06      0.05      5000
#
# [+] Start Test 5 epoch
# |                     Building network (0%)                    | ETA:  --:--:--
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Build finished in 0:00:02
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:12
# Build finished in 0:00:15
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:12
# Build finished in 0:00:12
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:11
# Build finished in 0:00:02
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:11
# Build finished in 0:00:02
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:12
# Build finished in 0:00:02
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:27
# Build finished in 0:00:02
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:11
# Build finished in 0:00:02
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:27
# Build finished in 0:00:02
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:14
# Build finished in 0:00:13
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Simulation finished in 0:01:11
# [+] Test Metrics
#               precision    recall  f1-score   support
#
#            0       0.82      0.86      0.84       980
#            1       0.87      0.91      0.89      1135
#            2       0.82      0.78      0.80      1032
#            3       0.77      0.83      0.80      1010
#            4       0.76      0.81      0.78       982
#            5       0.77      0.72      0.75       892
#            6       0.79      0.80      0.80       958
#            7       0.83      0.82      0.83      1028
#            8       0.76      0.73      0.74       974
#            9       0.81      0.74      0.78      1009
#
#     accuracy                           0.80     10000
#    macro avg       0.80      0.80      0.80     10000
# weighted avg       0.80      0.80      0.80     10000
